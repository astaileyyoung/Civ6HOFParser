# %%
import re 

import pandas as pd
import plotly.express as px
from plotly import graph_objects as go

from watch import get_leaders

# %%
leaders_df = pd.DataFrame(get_leaders('/home/amos/.local/share/aspyr-media/Sid Meier\'s Civilization VI/Logs/GameCore.log'))
leaders_df = leaders_df[leaders_df['civilization_type'] == 'FULL_CIV']
leaders_df['civilization'] = leaders_df['civilization'].map(lambda x: f'CIVILIZATION_{x.strip()}')
leaders_df
# Out:
#    player_id            civilization               leader civilization_type  \
# 0          0    CIVILIZATION_OTTOMAN             SULEIMAN          FULL_CIV
# 1          1  CIVILIZATION_PHOENICIA                 DIDO          FULL_CIV
# 2          2       CIVILIZATION_CREE           POUNDMAKER          FULL_CIV
# 3          3    CIVILIZATION_SUMERIA            GILGAMESH          FULL_CIV
# 4          4     CIVILIZATION_CANADA              LAURIER          FULL_CIV
# 5          5     CIVILIZATION_NORWAY             HARDRADA          FULL_CIV
# 6          6      CIVILIZATION_JAPAN                 HOJO          FULL_CIV
# 7          7      CIVILIZATION_AZTEC            MONTEZUMA          FULL_CIV
# 8          8     CIVILIZATION_FRANCE  CATHERINE DE MEDICI          FULL_CIV
# 9          9      CIVILIZATION_KOREA             SEONDEOK          FULL_CIV
#
#   player_type
# 0       Human
# 1          AI
# 2          AI
# 3          AI
# 4          AI
# 5          AI
# 6          AI
# 7          AI
# 8          AI
# 9          AI

# %%
def process_csv_pandas(input_filepath, num_expected_columns):
    """
    Reads a CSV file using pandas and puts extra entries into the final column.

    Args:
        input_filepath (str): Path to the input CSV file.
        output_filepath (str): Path to the output CSV file.
        num_expected_columns (int): The number of columns you expect (the last one will hold extras).
    """
    df = pd.read_csv(input_filepath, header=None, dtype=str)  # Read without header, as strings

    def combine_extras(row):
        if len(row) > num_expected_columns:
            extras = row[num_expected_columns - 1:].astype(str).str.cat(sep=' ')
            processed_row = list(row[:num_expected_columns - 1]) + [extras]
            return pd.Series(processed_row)
        else:
            return row

    processed_df = df.apply(combine_extras, axis=1)
    processed_df.columns = [f'col_{i+1}' for i in range(processed_df.shape[1])] # Optional: Rename columns
    return processed_df

# %%
ai_df = pd.read_csv('/home/amos/.local/share/aspyr-media/Sid Meier\'s Civilization VI/Logs/AI_CityBuild.csv', header=None, dtype=str, skiprows=1)
ai_df = ai_df.drop(columns=[12, 13], axis=1)  # Drop the first column
# df[' Player'] = df[' Player'].map(lambda x: x.strip())
ai_df.columns = ['Game Turn', 'Player', 'City', 'Food Adv.', 'Prod. Adv.', 'Construct', 'Food', 'Production', 'Gold', 'Science', 'Culture', 'Faith']
ai_df['Player'] = ai_df['Player'].map(lambda x: int(x.strip()))
ai_df
# Out:
#     Game Turn  Player                           City Food Adv.     Prod. Adv.  \
# 0           1       0         LOC_CITY_NAME_ISTANBUL     -0.02           4.31
# 1           1       2   LOC_CITY_NAME_MIKISIW_WACIHK      0.90           1.36
# 2           1       2   LOC_CITY_NAME_MIKISIW_WACIHK
# 3           1       3             LOC_CITY_NAME_URUK      0.72           0.38
# 4           1       3             LOC_CITY_NAME_URUK
# ..        ...     ...                            ...       ...            ...
# 768        25      16    LOC_CITY_NAME_BANDAR_BRUNEI             CONTRACT 760
# 769        25      17           LOC_CITY_NAME_LISBON
# 770        25      17           LOC_CITY_NAME_LISBON
# 771        25      22                       PURCHASE
# 772        25      24     LOC_CITY_NAME_ANTANANARIVO
#
#                                      Construct                     Food  \
# 0                                                       YIELD_FOOD: 0.0
# 1                                                       YIELD_FOOD: 0.0
# 2                            BUILDING_MONUMENT   Default Specialization
# 3                                                       YIELD_FOOD: 0.1
# 4                                   UNIT_SCOUT   Default Specialization
# ..                                         ...                      ...
# 768                                  SUBMITTED             UNIT_BUILDER
# 769   NO BUILDS AT ALL (maybe city was nuked?)          Generic Offense
# 770   NO BUILDS AT ALL (maybe city was nuked?)          Generic Offense
# 771                               UNIT_BUILDER   Build City Improvement
# 772                               UNIT_WARRIOR   Default Specialization
#
#                  Production               Gold              Science  \
# 0     YIELD_PRODUCTION: 0.1   YIELD_GOLD: -0.1   YIELD_SCIENCE: 0.0
# 1     YIELD_PRODUCTION: 0.1   YIELD_GOLD: -0.1   YIELD_SCIENCE: 0.0
# 2                                                        Value 20.9
# 3     YIELD_PRODUCTION: 0.0    YIELD_GOLD: 0.0   YIELD_SCIENCE: 0.0
# 4                                                        Value 34.8
# ..                      ...                ...                  ...
# 768             NO_BUILDING        NO_DISTRICT          VALUE 115.0
# 769                     NaN                NaN                  NaN
# 770                     NaN                NaN                  NaN
# 771            CONTRACT 734                NaN                  NaN
# 772                                                      Value 19.3
#
#                      Culture               Faith
# 0         YIELD_CULTURE: 0.0    YIELD_FAITH: 0.0
# 1         YIELD_CULTURE: 0.0    YIELD_FAITH: 0.0
# 2                        NaN                 NaN
# 3         YIELD_CULTURE: 0.0   YIELD_FAITH: -0.1
# 4                        NaN                 NaN
# ..                       ...                 ...
# 768   Build City Improvement                 NaN
# 769                      NaN                 NaN
# 770                      NaN                 NaN
# 771                      NaN                 NaN
# 772                      NaN                 NaN
#
# [773 rows x 12 columns]

# %%
player = ai_df[ai_df['Player'] == 2]
player
# Out:
#     Game Turn  Player                               City Food Adv.  \
# 1           1       2       LOC_CITY_NAME_MIKISIW_WACIHK      0.90
# 2           1       2       LOC_CITY_NAME_MIKISIW_WACIHK
# 49          2       2       LOC_CITY_NAME_MIKISIW_WACIHK
# 50          2       2       LOC_CITY_NAME_MIKISIW_WACIHK
# 69          3       2       LOC_CITY_NAME_MIKISIW_WACIHK
# ..        ...     ...                                ...       ...
# 724        25       2   LOC_CITY_NAME_PIHTOKAHANAPIWIYIN
# 725        25       2   LOC_CITY_NAME_PIHTOKAHANAPIWIYIN
# 726        25       2   LOC_CITY_NAME_PIHTOKAHANAPIWIYIN
# 727        25       2   LOC_CITY_NAME_PIHTOKAHANAPIWIYIN
# 728        25       2       LOC_CITY_NAME_PASKWAW_ASKIHK
#
#         Prod. Adv.           Construct                     Food  \
# 1             1.36                              YIELD_FOOD: 0.0
# 2                    BUILDING_MONUMENT   Default Specialization
# 49     CONTRACT 10           SUBMITTED     UNIT_CREE_OKIHTCITAW
# 50     CONTRACT 11           SUBMITTED             UNIT_SLINGER
# 69                        UNIT_SLINGER       Build Trigger Unit
# ..             ...                 ...                      ...
# 724   CONTRACT 559           COMPLETED             UNIT_SETTLER
# 725   CONTRACT 652         IN PROGRESS             UNIT_BUILDER
# 726   CONTRACT 711         IN PROGRESS             UNIT_BUILDER
# 727                      UNIT_HORSEMAN   Default Specialization
# 728   CONTRACT 741           SUBMITTED                  NO_UNIT
#
#                  Production               Gold              Science  \
# 1     YIELD_PRODUCTION: 0.1   YIELD_GOLD: -0.1   YIELD_SCIENCE: 0.0
# 2                                                        Value 20.9
# 49              NO_BUILDING        NO_DISTRICT           VALUE 18.0
# 50              NO_BUILDING        NO_DISTRICT           VALUE 26.0
# 69              CONTRACT 11                NaN                  NaN
# ..                      ...                ...                  ...
# 724             NO_BUILDING        NO_DISTRICT          VALUE 478.0
# 725             NO_BUILDING        NO_DISTRICT          VALUE 102.0
# 726             NO_BUILDING        NO_DISTRICT          VALUE 274.0
# 727                                                      Value 51.2
# 728        BUILDING_GRANARY        NO_DISTRICT          VALUE 102.0
#
#                      Culture              Faith
# 1         YIELD_CULTURE: 0.0   YIELD_FAITH: 0.0
# 2                        NaN                NaN
# 49        Build Trigger Unit                NaN
# 50        Build Trigger Unit                NaN
# 69                       NaN                NaN
# ..                       ...                ...
# 724           Settle City Op                NaN
# 725   Build City Improvement                NaN
# 726   Build City Improvement                NaN
# 727                      NaN                NaN
# 728      Build City Building                NaN
#
# [82 rows x 12 columns]

# %%
df = pd.read_csv('/home/amos/.local/share/aspyr-media/Sid Meier\'s Civilization VI/Logs/City_BuildQueue.csv')
df.columns = [x.strip() for x in df.columns]
df
# Out:
#      Game Turn                           City  Production Added  \
# 0            2         LOC_CITY_NAME_ISTANBUL               5.0
# 1            2   LOC_CITY_NAME_MIKISIW_WACIHK               6.4
# 2            2             LOC_CITY_NAME_URUK               9.6
# 3            2           LOC_CITY_NAME_OTTAWA               8.0
# 4            2          LOC_CITY_NAME_NIDAROS               9.6
# ..         ...                            ...               ...
# 784         25          LOC_CITY_NAME_YEREVAN               2.8
# 785         25     LOC_CITY_NAME_ANTANANARIVO               3.5
# 786         26         LOC_CITY_NAME_ISTANBUL               9.9
# 787         26            LOC_CITY_NAME_BURSA               7.2
# 788         26            LOC_CITY_NAME_ADANA               5.0
#
#            Current Item  Current Production  Production Needed  Overflow
# 0            UNIT_SCOUT                 5.0                 15       0.0
# 1     BUILDING_MONUMENT                 6.4                 30       0.0
# 2            UNIT_SCOUT                 9.6                 15       0.0
# 3            UNIT_SCOUT                 8.0                 15       0.0
# 4            UNIT_SCOUT                 9.6                 15       0.0
# ..                  ...                 ...                ...       ...
# 784    BUILDING_GRANARY                11.4                 32       0.0
# 785         UNIT_TRADER                27.5                 25       2.5
# 786          UNIT_SCOUT                22.6                 15       7.6
# 787        UNIT_BUILDER                21.6                 27       0.0
# 788   BUILDING_MONUMENT                10.0                 30       0.0
#
# [789 rows x 7 columns]

# %%
ai_df.columns
# Out:
# Index(['Game Turn', 'Player', 'City', 'Food Adv.', 'Prod. Adv.', 'Construct',
#        'Food', 'Production', 'Gold', 'Science', 'Culture', 'Faith'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Game Turn', 'City', 'Production Added', 'Current Item',
#        'Current Production', 'Production Needed', 'Overflow'],
#       dtype='object')

# %%
leaders = ai_df[['Player', 'City']].drop_duplicates()
leaders
# Out:
#      Player                               City
# 0         0             LOC_CITY_NAME_ISTANBUL
# 1         2       LOC_CITY_NAME_MIKISIW_WACIHK
# 3         3                 LOC_CITY_NAME_URUK
# 5         4               LOC_CITY_NAME_OTTAWA
# 7         5              LOC_CITY_NAME_NIDAROS
# 9         6                LOC_CITY_NAME_KYOTO
# 11        7         LOC_CITY_NAME_TENOCHTITLAN
# 13        8                LOC_CITY_NAME_PARIS
# 15        9             LOC_CITY_NAME_GYEONGJU
# 17       10                LOC_CITY_NAME_HUNZA
# 19       11             LOC_CITY_NAME_AUCKLAND
# 21       12                  LOC_CITY_NAME_FEZ
# 23       13              LOC_CITY_NAME_VILNIUS
# 25       14            LOC_CITY_NAME_SAMARKAND
# 27       15           LOC_CITY_NAME_NGAZARGAMU
# 29       16        LOC_CITY_NAME_BANDAR_BRUNEI
# 31       17               LOC_CITY_NAME_LISBON
# 33       18                LOC_CITY_NAME_KANDY
# 35       19                LOC_CITY_NAME_KABUL
# 37       20              LOC_CITY_NAME_HATTUSA
# 39       21              LOC_CITY_NAME_ANTIOCH
# 41       22         LOC_CITY_NAME_MOHENJO_DARO
# 43       23              LOC_CITY_NAME_YEREVAN
# 45       24         LOC_CITY_NAME_ANTANANARIVO
# 47        1                 LOC_CITY_NAME_TYRE
# 91        8             LOC_CITY_NAME_TOULOUSE
# 94        4          LOC_CITY_NAME_QUEBEC_CITY
# 102       7        LOC_CITY_NAME_ATZCAPOTZALCO
# 124       3           LOC_CITY_NAME_BAD_TIBIRA
# 148       1                LOC_CITY_NAME_SIDON
# 150       2   LOC_CITY_NAME_PIHTOKAHANAPIWIYIN
# 156       6            LOC_CITY_NAME_TAKAMATSU
# 183       9            LOC_CITY_NAME_GANGNEUNG
# 277       6                           PURCHASE
# 283       7          LOC_CITY_NAME_TEOTIHUACAN
# 285       8                           PURCHASE
# 289       8               LOC_CITY_NAME_NANTES
# 343       0                LOC_CITY_NAME_BURSA
# 359       5                           PURCHASE
# 382       3                           PURCHASE
# 387       4             LOC_CITY_NAME_WINNIPEG
# 412      11                           PURCHASE
# 415      21                           PURCHASE
# 426       2       LOC_CITY_NAME_PASKWAW_ASKIHK
# 440       5                 LOC_CITY_NAME_OSLO
# 459       9            LOC_CITY_NAME_CHUNCHEON
# 498       7                           PURCHASE
# 549       7              LOC_CITY_NAME_ANTIOCH
# 564      24                           PURCHASE
# 587       6                LOC_CITY_NAME_OSAKA
# 607      14                           PURCHASE
# 609      18                           PURCHASE
# 680       0                LOC_CITY_NAME_ADANA
# 771      22                           PURCHASE

# %%
merged = df.merge(leaders,
              how='left',
              on='City')
merged
# Out:
#      Game Turn                           City  Production Added  \
# 0            2         LOC_CITY_NAME_ISTANBUL               5.0
# 1            2   LOC_CITY_NAME_MIKISIW_WACIHK               6.4
# 2            2             LOC_CITY_NAME_URUK               9.6
# 3            2           LOC_CITY_NAME_OTTAWA               8.0
# 4            2          LOC_CITY_NAME_NIDAROS               9.6
# ..         ...                            ...               ...
# 802         25          LOC_CITY_NAME_YEREVAN               2.8
# 803         25     LOC_CITY_NAME_ANTANANARIVO               3.5
# 804         26         LOC_CITY_NAME_ISTANBUL               9.9
# 805         26            LOC_CITY_NAME_BURSA               7.2
# 806         26            LOC_CITY_NAME_ADANA               5.0
#
#            Current Item  Current Production  Production Needed  Overflow  \
# 0            UNIT_SCOUT                 5.0                 15       0.0
# 1     BUILDING_MONUMENT                 6.4                 30       0.0
# 2            UNIT_SCOUT                 9.6                 15       0.0
# 3            UNIT_SCOUT                 8.0                 15       0.0
# 4            UNIT_SCOUT                 9.6                 15       0.0
# ..                  ...                 ...                ...       ...
# 802    BUILDING_GRANARY                11.4                 32       0.0
# 803         UNIT_TRADER                27.5                 25       2.5
# 804          UNIT_SCOUT                22.6                 15       7.6
# 805        UNIT_BUILDER                21.6                 27       0.0
# 806   BUILDING_MONUMENT                10.0                 30       0.0
#
#      Player
# 0         0
# 1         2
# 2         3
# 3         4
# 4         5
# ..      ...
# 802      23
# 803      24
# 804       0
# 805       0
# 806       0
#
# [807 rows x 8 columns]

# %%
merged[merged.duplicated(subset=['Game Turn', 'City', 'Player'], keep=False)]
# Out:
#      Game Turn                           City  Production Added  \
# 361         14     LOC_CITY_NAME_TENOCHTITLAN              29.3
# 362         14    LOC_CITY_NAME_ATZCAPOTZALCO              11.2
# 363         14     LOC_CITY_NAME_TENOCHTITLAN              13.0
# 364         14    LOC_CITY_NAME_ATZCAPOTZALCO              13.0
# 388         15   LOC_CITY_NAME_MIKISIW_WACIHK              16.0
# 390         15   LOC_CITY_NAME_MIKISIW_WACIHK              26.2
# 405         15            LOC_CITY_NAME_HUNZA               3.5
# 406         15            LOC_CITY_NAME_HUNZA              15.5
# 410         15        LOC_CITY_NAME_SAMARKAND              15.0
# 411         15        LOC_CITY_NAME_SAMARKAND              14.0
# 414         15           LOC_CITY_NAME_LISBON              21.0
# 415         15           LOC_CITY_NAME_LISBON              14.0
# 431         16           LOC_CITY_NAME_OTTAWA              22.2
# 433         16           LOC_CITY_NAME_OTTAWA              14.0
# 559         19       LOC_CITY_NAME_NGAZARGAMU               5.0
# 560         19       LOC_CITY_NAME_NGAZARGAMU              17.0
# 575         20   LOC_CITY_NAME_MIKISIW_WACIHK              20.8
# 577         20   LOC_CITY_NAME_MIKISIW_WACIHK              17.0
# 717         23    LOC_CITY_NAME_BANDAR_BRUNEI               4.0
# 718         23    LOC_CITY_NAME_BANDAR_BRUNEI              17.0
# 757         24            LOC_CITY_NAME_KANDY               2.4
# 758         24            LOC_CITY_NAME_KANDY               9.0
# 763         24     LOC_CITY_NAME_ANTANANARIVO               6.0
# 764         24     LOC_CITY_NAME_ANTANANARIVO              18.0
#
#              Current Item  Current Production  Production Needed  Overflow  \
# 361   BUILDING_STONEHENGE                29.3                 90       0.0
# 362    DISTRICT_HOLY_SITE                24.4                 34       0.0
# 363   BUILDING_STONEHENGE                42.3                 90       0.0
# 364    DISTRICT_HOLY_SITE                37.4                 34       3.4
# 388      BUILDING_GRANARY                44.2                 32      12.2
# 390           UNIT_ARCHER                26.2                 30       0.0
# 405     BUILDING_MONUMENT                31.5                 30       1.5
# 406      BUILDING_GRANARY                15.5                 32       0.0
# 410          UNIT_WARRIOR                30.0                 20       0.0
# 411      BUILDING_GRANARY                14.0                 32       0.0
# 414          UNIT_WARRIOR                21.0                 20       0.0
# 415      BUILDING_GRANARY                14.0                 32       0.0
# 431          UNIT_BUILDER                22.2                 29       0.0
# 433          UNIT_BUILDER                36.2                 29       7.2
# 559     BUILDING_MONUMENT                 7.5                 30       0.0
# 560     BUILDING_MONUMENT                24.5                 30       0.0
# 575           UNIT_ARCHER                20.8                 30       0.0
# 577           UNIT_ARCHER                37.8                 30       7.8
# 717           UNIT_TRADER                12.5                 24       0.0
# 718           UNIT_TRADER                29.5                 24       5.5
# 757      BUILDING_GRANARY                12.0                 32       0.0
# 758      BUILDING_GRANARY                21.0                 32       0.0
# 763           UNIT_TRADER                 6.0                 25       0.0
# 764           UNIT_TRADER                24.0                 25       0.0
#
#      Player
# 361       7
# 362       7
# 363       7
# 364       7
# 388       2
# 390       2
# 405      10
# 406      10
# 410      14
# 411      14
# 414      17
# 415      17
# 431       4
# 433       4
# 559      15
# 560      15
# 575       2
# 577       2
# 717      16
# 718      16
# 757      18
# 758      18
# 763      24
# 764      24

# %%
df[df.duplicated(subset=['Game Turn', 'City', 'Production Added'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Game Turn, City, Production Added, Current Item, Current Production, Production Needed, Overflow]
# Index: []

# %%
merged[merged['City'] == ' LOC_CITY_NAME_ANTIOCH']
# Out:
#      Game Turn                    City  Production Added        Current Item  \
# 20           2   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_SLINGER
# 21           2   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_SLINGER
# 36           3   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_SLINGER
# 37           3   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_SLINGER
# 60           4   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_SLINGER
# 61           4   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_SLINGER
# 87           5   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 88           5   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 115          6   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 116          6   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 143          7   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 144          7   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 175          8   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 176          8   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 208          9   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 209          9   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 242         10   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 243         10   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 276         11   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 277         11   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 310         12   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 311         12   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 344         13   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 345         13   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 380         14   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 381         14   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 419         15   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 420         15   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 454         16   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 455         16   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 490         17   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 491         17   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 526         18   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 527         18   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 566         19   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 567         19   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
#
#      Current Production  Production Needed  Overflow  Player
# 20                  6.0                 17       0.0      21
# 21                  6.0                 17       0.0       7
# 36                 12.0                 17       0.0      21
# 37                 12.0                 17       0.0       7
# 60                 18.0                 17       0.0      21
# 61                 18.0                 17       0.0       7
# 87                  2.0                 30       0.0      21
# 88                  2.0                 30       0.0       7
# 115                 4.0                 30       0.0      21
# 116                 4.0                 30       0.0       7
# 143                 6.0                 30       0.0      21
# 144                 6.0                 30       0.0       7
# 175                 8.0                 30       0.0      21
# 176                 8.0                 30       0.0       7
# 208                10.0                 30       0.0      21
# 209                10.0                 30       0.0       7
# 242                12.0                 30       0.0      21
# 243                12.0                 30       0.0       7
# 276                14.0                 30       0.0      21
# 277                14.0                 30       0.0       7
# 310                16.0                 30       0.0      21
# 311                16.0                 30       0.0       7
# 344                18.0                 30       0.0      21
# 345                18.0                 30       0.0       7
# 380                20.0                 30       0.0      21
# 381                20.0                 30       0.0       7
# 419                22.0                 30       0.0      21
# 420                22.0                 30       0.0       7
# 454                 6.0                 20       0.0      21
# 455                 6.0                 20       0.0       7
# 490                12.0                 20       0.0      21
# 491                12.0                 20       0.0       7
# 526                18.0                 20       0.0      21
# 527                18.0                 20       0.0       7
# 566                24.0                 20       0.0      21
# 567                24.0                 20       0.0       7

# %%
df[df['City'] == ' LOC_CITY_NAME_ANTIOCH']
# Out:
#      Game Turn                    City  Production Added        Current Item  \
# 20           2   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_SLINGER
# 35           3   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_SLINGER
# 58           4   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_SLINGER
# 84           5   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 111          6   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 138          7   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 169          8   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 201          9   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 234         10   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 267         11   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 300         12   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 333         13   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 368         14   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 406         15   LOC_CITY_NAME_ANTIOCH               2.0   BUILDING_MONUMENT
# 440         16   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 475         17   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 510         18   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
# 549         19   LOC_CITY_NAME_ANTIOCH               6.0        UNIT_WARRIOR
#
#      Current Production  Production Needed  Overflow
# 20                  6.0                 17       0.0
# 35                 12.0                 17       0.0
# 58                 18.0                 17       0.0
# 84                  2.0                 30       0.0
# 111                 4.0                 30       0.0
# 138                 6.0                 30       0.0
# 169                 8.0                 30       0.0
# 201                10.0                 30       0.0
# 234                12.0                 30       0.0
# 267                14.0                 30       0.0
# 300                16.0                 30       0.0
# 333                18.0                 30       0.0
# 368                20.0                 30       0.0
# 406                22.0                 30       0.0
# 440                 6.0                 20       0.0
# 475                12.0                 20       0.0
# 510                18.0                 20       0.0
# 549                24.0                 20       0.0
